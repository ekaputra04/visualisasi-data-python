# %% [markdown]
# Visualisasi Data yang Tersimpan pada Pandas Data Frame

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Sample Dataset

# %%
df = pd.DataFrame({
  'nama': ['Cecep', 'Karti', 'Bejo', 'Tejo', 'Asep', 'Wati', 'Amat'],
  'usia': [23, 78, 22, 19, 45, 33, 20],
  'gender': ['L', 'P', 'L', 'L', 'L', 'P', 'L'],
  'provinsi': ['Jawa Timur', 'Jawa Barat', 'Jawa Barat', 'Jawa Timur', 'Jawa Tengah', 'Bali', 'Bali'],
  'n_anak': [3, 2, 1, 1, 3, 2, 2],
  'n_pets': [0, 2, 1, 4, 2, 1, 2]
})

df
# Out:
#     nama  usia gender     provinsi  n_anak  n_pets
# 0  Cecep    23      L   Jawa Timur       3       0
# 1  Karti    78      P   Jawa Barat       2       2
# 2   Bejo    22      L   Jawa Barat       1       1
# 3   Tejo    19      L   Jawa Timur       1       4
# 4   Asep    45      L  Jawa Tengah       3       2
# 5   Wati    33      P         Bali       2       1
# 6   Amat    20      L         Bali       2       2

# %% [markdown]
# Scatter Plot

# %%
df.plot(kind='scatter', x='n_anak', y='n_pets', color='red')

plt.title('Scatter Plot')
plt.xlabel('Jumlah Anak')
plt.ylabel('Jumlah Pets')
plt.show()

# %% [markdown]
# Histogram

# %%
df[['usia']].plot(kind='hist', bins=[0, 20, 40, 60, 80, 100])

plt.title('Histogram')
plt.xlabel('Usia')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# Line Plot

# %%
df.plot(kind='line', x='nama', y='n_anak', color='green')

plt.title('Line Plot')
plt.xlabel('Nama')
plt.ylabel('Jumlah Anak')
plt.show()

# %% [markdown]
# Multiple Line Plot

# %%
ax = plt.gca()

df.plot(kind='line', x='nama', y='n_anak', color='green', ax=ax)
df.plot(kind='line', x='nama', y='n_pets', color='red', ax=ax)

plt.title('Multiple Line Plot')
plt.xlabel('Nama')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# Bar Plot

# %%
df.plot(kind='bar', x='nama', y='usia')

plt.title('Bar Plot')
plt.xlabel('Nama')
plt.ylabel('Usia')
plt.show()

# %% [markdown]
# Bar Plot berdasarkan kelompok tertentu

# %%
df.groupby('provinsi')['nama'].count().plot(kind='bar')

plt.title('Multiple Line Plot')
plt.xlabel('Nama')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# Stacked Bar Plot dengan Dua Level Group By

# %%
df.groupby(['provinsi', 'gender']).size().unstack().plot(kind='bar', stacked=True)

plt.title('Stacked Bar Plot')
plt.xlabel('Provinsi')
plt.ylabel('Jumlah')
plt.show()

# %%
df.groupby(['gender', 'provinsi']).size().unstack().plot(kind='bar', stacked=True)

plt.title('Stacked Bar Plot')
plt.xlabel('Provinsi')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# Line Plot

# %%
data = {
  'tahun': [
    1958, 1963, 1968, 1973, 1978, 1983, 1988, 1993, 1998, 2003, 2008, 2013, 2018
  ],
  'populasi': [
    51738200, 52382600, 53482800, 54442800, 55639400, 55947200, 56263000, 56582700, 56928300, 57283620, 57618200, 58927100, 59218300 
  ]
}

df = pd.DataFrame(data)
df
# Out:
#     tahun  populasi
# 0    1958  51738200
# 1    1963  52382600
# 2    1968  53482800
# 3    1973  54442800
# 4    1978  55639400
# 5    1983  55947200
# 6    1988  56263000
# 7    1993  56582700
# 8    1998  56928300
# 9    2003  57283620
# 10   2008  57618200
# 11   2013  58927100
# 12   2018  59218300

# %%
df.plot(x='tahun', y='populasi', kind='line')

plt.title('Line Plot')
plt.xlabel('Tahun')
plt.ylabel('Populasi')
plt.show()

# %% [markdown]
# Bar Plot

# %%
data = {
  'negara': ['United States', 'Singapore', 'Germany', 'United Kingdom', 'Japan'] ,
  'gdp': [62686, 100345, 52559, 45705, 44227]
}

df = pd.DataFrame(data, columns=['negara', 'gdp'])
df
# Out:
#            negara     gdp
# 0   United States   62686
# 1       Singapore  100345
# 2         Germany   52559
# 3  United Kingdom   45705
# 4           Japan   44227

# %%
df.plot(x='negara', y='gdp', kind='bar')

plt.title('Bar Plot')
plt.xlabel('Negara')
plt.ylabel('GDP')
plt.show()

# %% [markdown]
# Horizontal Bar Plot

# %%
df.plot(x='negara', y='gdp', kind='barh')

plt.title('Bar Horizontal Plot')
plt.xlabel('GDP')
plt.ylabel('Negara')
plt.show()

# %% [markdown]
# Scatter Plot

# %%
data = {
  'negara': ['United States', 'Singapore', 'Germany', 'United Kingdom', 'Japan'] ,
  'gdp': [62686, 100345, 52559, 45705, 44227],
  'life_expectancy': [79.24, 82.84, 80.64, 81.40, 83.62]
}

df = pd.DataFrame(data, columns=['negara', 'gdp', 'life_expectancy'])
df
# Out:
#            negara     gdp  life_expectancy
# 0   United States   62686            79.24
# 1       Singapore  100345            82.84
# 2         Germany   52559            80.64
# 3  United Kingdom   45705            81.40
# 4           Japan   44227            83.62

# %%
df.plot(x='gdp', y='life_expectancy', kind='scatter')

plt.title('Scatter Plot')
plt.xlabel('GDP dan USD')
plt.ylabel('Life Expectancy')
plt.show()

# %% [markdown]
# Pie Plot

# %%
data = {
  'negara': ['United States', 'Singapore', 'Germany', 'United Kingdom', 'Japan'] ,
  'gdp': [62686, 100345, 52559, 45705, 44227]
}

df = pd.DataFrame(data, columns=['negara', 'gdp'])
df = df.set_index('negara') # untuk mengubah agar index bukan angka melainkan kolom tertentu
df
# Out:
#                    gdp
# negara
# United States    62686
# Singapore       100345
# Germany          52559
# United Kingdom   45705
# Japan            44227

# %%
df.plot(kind='pie', y='gdp', figsize=(6, 6))
plt.title('GDP')
plt.show()

# %% [markdown]
# Box Plot

# %%
data = {
  'negara': ['United States', 'Singapore', 'Germany', 'United Kingdom', 'Japan'] ,
  'gdp': [62686, 100345, 52559, 45705, 44227]
}

df = pd.DataFrame(data, columns=['negara', 'gdp'])
df
# Out:
#            negara     gdp
# 0   United States   62686
# 1       Singapore  100345
# 2         Germany   52559
# 3  United Kingdom   45705
# 4           Japan   44227

# %%
df['gdp'].plot(kind='box')

plt.title('Box Plot')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# Bagian 3 - Sample csv Dataset

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('./dataset/2020.csv')
df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %% [markdown]
# Mengganti Nama Kolom

# %%
df.rename(
  columns={
  'Country name': 'Country',
  'Perceptions of corruption': 'Corruption',
  'Freedom to make life choices': 'Freedom'
  },
  inplace=True)

df.columns
# Out:
# Index(['Country', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom', 'Generosity', 'Corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %% [markdown]
# Bar Plot

# %%
df[:5].plot(
  x='Country',
  y=['Corruption', 'Freedom', 'Generosity', 'Social support'],
  kind="bar"
)

# Menyesuaikan label sumbu x agar miring
plt.xticks(rotation=45)

plt.title('Contoh Bar Plot')
plt.xlabel('Negara')
plt.ylabel('Nilai')
plt.show()

# %% [markdown]
# Line Plot

# %%
df[:5].plot(
  x='Country',
  y=['Corruption', 'Freedom', 'Generosity', 'Social support'],
  kind="line"
)

# Menyesuaikan label sumbu x agar miring
plt.xticks(rotation=45)

plt.title('Contoh Line Plot')
plt.xlabel('Negara')
plt.ylabel('Nilai')
plt.show()

# %% [markdown]
# Box Plot

# %%
df.plot(
  y=['Corruption', 'Freedom', 'Generosity', 'Social support'],
  kind="box"
)

# Menyesuaikan label sumbu x agar miring
plt.xticks(rotation=45)

plt.title('Contoh Box Plot')
plt.xlabel('Negara')
plt.ylabel('Nilai')
plt.show()

# %% [markdown]
# Scatter Plot

# %%
df.plot(
  x='Corruption',
  y='Freedom',
  kind="scatter"
)

# mengatur ukuran kanvas
plt.xlim((0, 1))
plt.ylim((0, 1))

plt.title('Contoh Scatter Plot')
plt.show()

# %% [markdown]
# Histogram

# %%
df.plot(
  x='Country',
  y='Freedom',
  kind="hist"
)

plt.title('Contoh Histogram')
plt.show()

# %%
df.plot(
  x='Country',
  y=['Corruption', 'Freedom', 'Generosity', 'Social support'],
  kind="hist",
  subplots=True,
  layout=(2, 2)
)

plt.suptitle('Contoh Histogram Kompleks')
plt.tight_layout()
plt.show()
