# %% [markdown]
# Histogram

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.8.2
# 1.26.0

# %%
mu = 100
sigma = 15

x = mu + sigma * np.random.randn(10000) # normal distribution
x
# Out:
# array([ 93.49402805,  79.75647017, 100.38697939, ..., 119.94658889,
#         89.25161969,  96.11209069])

# %%
x.shape
# Out:
# (10000,)

# %% [markdown]
# Histogram dengan pyplot Style

# %%
plt.hist(
  x,
  bins=100,
  facecolor='g',
  alpha=0.75
)
plt.xlabel('Sumbu x')
plt.ylabel('Sumbu y')
plt.title('Contoh Histogram')

plt.text(45, 300, '$\mu=100,\ \sigma=15$')
plt.grid()
plt.show()

# %% [markdown]
# Histogram dengan OO Style

# %%
fig, ax = plt.subplots()
ax.hist(
  x,
  bins=100,
  facecolor='b',
  alpha=0.75
)

ax.set_xlabel('Sumbu x')
ax.set_ylabel('Sumbu y')
ax.set_title('Contoh Histogram')

ax.text(45, 300, '$\mu=100,\ \sigma=15$')
ax.grid()
plt.show()
